# %%
# enable autocomplete
# %config IPCompleter.greedy=True

# %%
import json
with open('articles.json', 'r') as f:
    articles = json.load(f)

# %%
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO)

print(articles[1].keys())
print(articles[1]['url'])
# Out:
# dict_keys(['feed', 'source_id', 'url', 'title', 'top_image', 'movies', 'keywords', 'tags', 'authors', 'publish_date', 'summary', 'html', 'meta_data', 'language', 'text', 'vector', 'vector_2d'])
# https://blog.fefe.de/?ts=a5add387

# %%
articles_by_language = {}

for article in articles:
    language = article.get('language', 'none')
    if not language:
        #print(article['text'][:100])
        pass
    articles_in_language = articles_by_language.get(language, False)
    if not articles_in_language:
        articles_by_language[language] = []
    articles_by_language[language].append(article)

articles_by_url = {article['url']: article for article in articles}
    
# sort
for language in articles_by_language.keys():
    articles_by_language[language] = sorted(articles_by_language[language], 
                                            key=lambda article: article['publish_date'])
    
for language in articles_by_language.keys():
    print(f'{language}: {len(articles_by_language[language])}')
# Out:
# de: 12354
# en: 1820
# : 15

# %%
from gensim.models.doc2vec import TaggedDocument
from nltk.tokenize import word_tokenize
from gensim.models.doc2vec import Doc2Vec

def preprocess_text(text):
    text = text.lower()

    # remove whitespaces
    text = ' '.join(text.strip().split())

    text = text.replace('ä', 'ae') \
        .replace('ö', 'oe') \
        .replace('ü', 'ue')

    return text.split('.')


def train_model(all_docs, vec_size=100, alpha=0.025, min_alpha=0.00025, min_count=2, epochs=40):
    tagged_data = [TaggedDocument(words=word_tokenize(' '.join(preprocess_text(doc['text']))),
                                  tags=[doc['url']]) for doc in all_docs if doc.get('text', False)]
    logging.info(f'tagged {len(tagged_data)} of {len(all_docs)} docs')
    
    model = Doc2Vec(vector_size=vec_size,
                    alpha=alpha,
                    min_alpha=min_alpha,
                    min_count=min_count,
                    epochs=epochs)

    model.build_vocab(tagged_data)
    logging.info('training....')
    model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)
    return model

# %%
# needed on first run
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# %%time
#german_articles = articles_by_language['de']

DIMENSIONS = 100
model = train_model(articles_by_language['de'], vec_size=DIMENSIONS, min_count=20)
# Out:
# 2018-09-18 21:42:34,724 INFO:tagged 12138 of 12354 docs
# 2018-09-18 21:42:34,724 INFO:collecting all words and their counts
# 2018-09-18 21:42:34,725 INFO:PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-09-18 21:42:35,986 INFO:PROGRESS: at example #10000, processed 4437618 words (3521862/s), 209083 word types, 9995 tags
# 2018-09-18 21:42:36,281 INFO:collected 235768 word types and 12131 unique tags from a corpus of 12138 examples and 5514303 words
# 2018-09-18 21:42:36,282 INFO:Loading a fresh vocabulary
# 2018-09-18 21:42:36,459 INFO:effective_min_count=20 retains 17029 unique words (7% of original 235768, drops 218739)
# 2018-09-18 21:42:36,459 INFO:effective_min_count=20 leaves 4930654 word corpus (89% of original 5514303, drops 583649)
# 2018-09-18 21:42:36,568 INFO:deleting the raw counts dictionary of 235768 items
# 2018-09-18 21:42:36,577 INFO:sample=0.001 downsamples 53 most-common words
# 2018-09-18 21:42:36,582 INFO:downsampling leaves estimated 3723992 word corpus (75.5% of prior 4930654)
# 2018-09-18 21:42:36,695 INFO:estimated required memory for 17029 words and 100 dimensions: 29416300 bytes
# 2018-09-18 21:42:36,696 INFO:resetting layer weights
# 2018-09-18 21:42:37,125 INFO:training....
# 2018-09-18 21:42:37,126 INFO:training model with 3 workers on 17029 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 
INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:43:40,155 INFO:EPOCH - 12 : training on 5514303 raw words (3735599 effective words) took 6.0s, 620015 effective words/s
# 2018-09-18 21:43:41,166 INFO:EPOCH 13 - PROGRESS: at 23.73% examples, 747626 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:42,173 INFO:EPOCH 13 - PROGRESS: at 45.81% examples, 773730 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:43,176 INFO:EPOCH 13 - PROGRESS: at 65.69% examples, 777102 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:44,187 INFO:EPOCH 13 - PROGRESS: at 81.24% examples, 735795 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:45,203 INFO:EPOCH 13 - PROGRESS: at 97.22% examples, 719600 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:45,342 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:43:45,349 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:43:45,358 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:43:45,359 INFO:EPOCH - 13 : training on 5514303 raw words (3737718 effective words) took 5.2s, 719263 effective words/s
# 2018-09-18 21:43:46,377 INFO:EPOCH 14 - PROGRESS: at 25.05% examples, 787813 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:47,380 INFO:EPOCH 14 - PROGRESS: at 42.24% examples, 704623 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:48,388 INFO:EPOCH 14 - PROGRESS: at 57.82% examples, 672861 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:49,402 INFO:EPOCH 14 - PROGRESS: at 71.16% examples, 634737 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:50,412 INFO:EPOCH 14 - PROGRESS: at 86.35% examples, 626845 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:51,310 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:43:51,313 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:43:51,327 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:43:51,327 INFO:EPOCH - 14 : training on 5514303 raw words (3735520 effective words) took 6.0s, 626712 effective words/s
# 2018-09-18 21:43:52,335 INFO:EPOCH 15 - PROGRESS: at 24.88% examples, 786940 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:53,346 INFO:EPOCH 15 - PROGRESS: at 42.25% examples, 704466 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:54,369 INFO:EPOCH 15 - PROGRESS: at 62.58% examples, 729777 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:55,380 INFO:EPOCH 15 - PROGRESS: at 74.41% examples, 663651 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:56,381 INFO:EPOCH 15 - PROGRESS: at 86.52% examples, 627965 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:43:57,388 INFO:EPOCH 15 - PROGRESS: at 97.24% examples, 598798 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:57,539 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:43:57,542 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:43:57,559 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:43:57,560 INFO:EPOCH - 15 : training on 5514303 raw words (3736520 effective words) took 6.2s, 599911 effective words/s
# 2018-09-18 21:43:58,576 INFO:EPOCH 16 - PROGRESS: at 20.84% examples, 640459 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:43:59,583 INFO:EPOCH 16 - PROGRESS: at 40.24% examples, 665462 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:00,588 INFO:EPOCH 16 - PROGRESS: at 58.51% examples, 681825 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:01,592 INFO:EPOCH 16 - PROGRESS: at 78.48% examples, 707502 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:02,597 INFO:EPOCH 16 - PROGRESS: at 97.24% examples, 721183 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:02,729 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:02,744 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:02,752 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:02,753 INFO:EPOCH - 16 : training on 5514303 raw words (3737264 effective words) took 5.2s, 720642 effective words/s
# 2018-09-18 21:44:03,762 INFO:EPOCH 17 - PROGRESS: at 23.95% examples, 754493 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:04,765 INFO:EPOCH 17 - PROGRESS: at 45.51% examples, 767812 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:05,778 INFO:EPOCH 17 - PROGRESS: at 64.21% examples, 755576 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:06,779 INFO:EPOCH 17 - PROGRESS: at 84.51% examples, 767276 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:07,634 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:07,638 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:07,645 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:07,646 INFO:EPOCH - 17 : training on 5514303 raw words (3734975 effective words) took 4.9s, 764381 effective words/s
# 2018-09-18 21:44:08,655 INFO:EPOCH 18 - PROGRESS: at 23.35% examples, 733588 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:09,659 INFO:EPOCH 18 - PROGRESS: at 44.43% examples, 747993 words/s, in_qsize 5, out_qsize 1
# 2018-09-18 21:44:10,673 INFO:EPOCH 18 - PROGRESS: at 64.21% examples, 755022 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:11,677 INFO:EPOCH 18 - PROGRESS: at 83.69% examples, 758323 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:12,530 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:12,539 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:12,549 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:12,551 INFO:EPOCH - 18 : training on 5514303 raw words (3736493 effective words) took 4.9s, 762549 effective words/s
# 2018-09-18 21:44:13,555 INFO:EPOCH 19 - PROGRESS: at 24.69% examples, 782061 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:14,562 INFO:EPOCH 19 - PROGRESS: at 45.51% examples, 767644 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:15,570 INFO:EPOCH 19 - PROGRESS: at 64.21% examples, 756856 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:16,577 INFO:EPOCH 19 - PROGRESS: at 83.09% examples, 752473 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:17,475 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:17,483 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:17,489 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:17,490 INFO:EPOCH - 19 : training on 5514303 raw words (3736634 effective words) took 4.9s, 757075 effective words/s
# 2018-09-18 21:44:18,498 INFO:EPOCH 20 - PROGRESS: at 23.73% examples, 746720 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:19,505 INFO:EPOCH 20 - PROGRESS: at 45.32% examples, 762906 words/s, in_qsize 4, out_qsize 1
# 2018-09-18 21:44:20,508 INFO:EPOCH 20 - PROGRESS: at 64.70% examples, 763253 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:21,520 INFO:EPOCH 20 - PROGRESS: at 84.86% examples, 769458 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:22,316 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:22,317 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:22,329 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:22,330 INFO:EPOCH - 20 : training on 5514303 raw words (3735291 effective words) took 4.8s, 772431 effective words/s
# 2018-09-18 21:44:23,344 INFO:EPOCH 21 - PROGRESS: at 24.11% examples, 756450 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:24,367 INFO:EPOCH 21 - PROGRESS: at 40.39% examples, 663868 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:25,369 INFO:EPOCH 21 - PROGRESS: at 57.28% examples, 663631 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:26,370 INFO:EPOCH 21 - PROGRESS: at 75.94% examples, 681331 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:27,380 INFO:EPOCH 21 - PROGRESS: at 94.49% examples, 695576 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:27,643 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:27,650 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:27,653 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:27,654 INFO:EPOCH - 21 : training on 5514303 raw words (3736213 effective words) took 5.3s, 702443 effective words/s
# 2018-09-18 21:44:28,662 INFO:EPOCH 22 - PROGRESS: at 23.95% examples, 755990 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:29,663 INFO:EPOCH 22 - PROGRESS: at 45.51% examples, 769977 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:30,664 INFO:EPOCH 22 - PROGRESS: at 64.70% examples, 766499 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:31,672 INFO:EPOCH 22 - PROGRESS: at 85.00% examples, 774079 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:32,444 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:32,458 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:32,459 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:32,461 INFO:EPOCH - 22 : training on 5514303 raw words (3735790 effective words) took 4.8s, 778254 effective words/s
# 2018-09-18 21:44:33,475 INFO:EPOCH 23 - PROGRESS: at 23.52% examples, 740157 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:34,479 INFO:EPOCH 23 - PROGRESS: at 46.01% examples, 777357 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:35,487 INFO:EPOCH 23 - PROGRESS: at 64.01% examples, 754220 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:36,491 INFO:EPOCH 23 - PROGRESS: at 80.57% examples, 729653 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:37,464 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:37,465 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:37,466 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:37,467 INFO:EPOCH - 23 : training on 5514303 raw words (3735918 effective words) took 5.0s, 747724 effective words/s
# 2018-09-18 21:44:38,486 INFO:EPOCH 24 - PROGRESS: at 25.06% examples, 786305 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:39,492 INFO:EPOCH 24 - PROGRESS: at 47.24% examples, 798717 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:40,502 INFO:EPOCH 24 - PROGRESS: at 68.13% examples, 805274 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:41,504 INFO:EPOCH 24 - PROGRESS: at 88.43% examples, 806195 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:42,077 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:42,078 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:42,092 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:42,093 INFO:EPOCH - 24 : training on 5514303 raw words (3736506 effective words) took 4.6s, 808938 effective words/s
# 2018-09-18 21:44:43,107 INFO:EPOCH 25 - PROGRESS: at 23.95% examples, 749426 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:44,111 INFO:EPOCH 25 - PROGRESS: at 45.81% examples, 772316 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:45,120 INFO:EPOCH 25 - PROGRESS: at 66.69% examples, 787240 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:46,121 INFO:EPOCH 25 - PROGRESS: at 87.05% examples, 792743 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:46,776 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:46,784 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:46,789 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:46,789 INFO:EPOCH - 25 : training on 5514303 raw words (3736326 effective words) took 4.7s, 796251 effective words/s
# 2018-09-18 21:44:47,796 INFO:EPOCH 26 - PROGRESS: at 25.09% examples, 795026 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:48,797 INFO:EPOCH 26 - PROGRESS: at 47.00% examples, 799009 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:49,801 INFO:EPOCH 26 - PROGRESS: at 67.82% examples, 806784 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:50,802 INFO:EPOCH 26 - PROGRESS: at 88.14% examples, 807697 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:51,396 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:51,398 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:51,407 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:51,409 INFO:EPOCH - 26 : training on 5514303 raw words (3736351 effective words) took 4.6s, 809903 effective words/s
# 2018-09-18 21:44:52,422 INFO:EPOCH 27 - PROGRESS: at 25.09% examples, 790511 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:44:53,433 INFO:EPOCH 27 - PROGRESS: at 47.39% examples, 801921 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:54,437 INFO:EPOCH 27 - PROGRESS: at 68.31% examples, 809159 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:55,442 INFO:EPOCH 27 - PROGRESS: at 88.91% examples, 811515 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:55,999 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:44:56,007 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:44:56,018 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:44:56,019 INFO:EPOCH - 27 : training on 5514303 raw words (3735566 effective words) took 4.6s, 811660 effective words/s
# 2018-09-18 21:44:57,035 INFO:EPOCH 28 - PROGRESS: at 25.45% examples, 801646 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:58,037 INFO:EPOCH 28 - PROGRESS: at 47.00% examples, 795048 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:44:59,038 INFO:EPOCH 28 - PROGRESS: at 66.39% examples, 785661 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:00,040 INFO:EPOCH 28 - PROGRESS: at 86.52% examples, 789693 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:00,835 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:00,837 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:00,847 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:00,848 INFO:EPOCH - 28 : training on 5514303 raw words (3736635 effective words) took 4.8s, 774896 effective words/s
# 2018-09-18 21:45:01,856 INFO:EPOCH 29 - PROGRESS: at 25.45% examples, 808082 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:02,857 INFO:EPOCH 29 - PROGRESS: at 47.39% examples, 808457 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:03,858 INFO:EPOCH 29 - PROGRESS: at 66.39% examples, 788006 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:04,870 INFO:EPOCH 29 - PROGRESS: at 83.09% examples, 753721 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:05,730 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:05,738 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:05,749 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:05,750 INFO:EPOCH - 29 : training on 5514303 raw words (3736321 effective words) took 4.9s, 763233 effective words/s
# 2018-09-18 21:45:06,769 INFO:EPOCH 30 - PROGRESS: at 23.18% examples, 721278 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:07,780 INFO:EPOCH 30 - PROGRESS: at 43.11% examples, 716984 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:08,797 INFO:EPOCH 30 - PROGRESS: at 63.50% examples, 741726 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:09,803 INFO:EPOCH 30 - PROGRESS: at 83.85% examples, 756100 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:10,679 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:10,679 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:10,696 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:10,696 INFO:EPOCH - 30 : training on 5514303 raw words (3736116 effective words) took 4.9s, 756401 effective words/s
# 2018-09-18 21:45:11,709 INFO:EPOCH 31 - PROGRESS: at 24.34% examples, 764570 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:12,720 INFO:EPOCH 31 - PROGRESS: at 44.14% examples, 738506 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:13,724 INFO:EPOCH 31 - PROGRESS: at 60.87% examples, 711320 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:14,728 INFO:EPOCH 31 - PROGRESS: at 78.68% examples, 708935 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:15,729 INFO:EPOCH 31 - PROGRESS: at 92.49% examples, 679963 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:16,245 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:16,251 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:16,257 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:16,258 INFO:EPOCH - 31 : training on 5514303 raw words (3735774 effective words) took 5.6s, 672388 effective words/s
# 2018-09-18 21:45:17,266 INFO:EPOCH 32 - PROGRESS: at 20.29% examples, 624419 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:18,281 INFO:EPOCH 32 - PROGRESS: at 38.91% examples, 638500 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:19,287 INFO:EPOCH 32 - PROGRESS: at 58.51% examples, 680942 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:20,291 INFO:EPOCH 32 - PROGRESS: at 78.79% examples, 710033 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:21,300 INFO:EPOCH 32 - PROGRESS: at 96.77% examples, 715879 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:21,450 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:21,465 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:21,479 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:21,482 INFO:EPOCH - 32 : training on 5514303 raw words (3735648 effective words) took 5.2s, 715693 effective words/s
# 2018-09-18 21:45:22,492 INFO:EPOCH 33 - PROGRESS: at 19.26% examples, 584924 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:23,494 INFO:EPOCH 33 - PROGRESS: at 37.77% examples, 619314 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:24,495 INFO:EPOCH 33 - PROGRESS: at 57.00% examples, 664808 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:25,521 INFO:EPOCH 33 - PROGRESS: at 73.33% examples, 656017 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:26,522 INFO:EPOCH 33 - PROGRESS: at 91.42% examples, 669780 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:26,994 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:27,011 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:27,016 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:27,017 INFO:EPOCH - 33 : training on 5514303 raw words (3735578 effective words) took 5.5s, 675534 effective words/s
# 2018-09-18 21:45:28,024 INFO:EPOCH 34 - PROGRESS: at 25.28% examples, 801311 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:29,026 INFO:EPOCH 34 - PROGRESS: at 46.69% examples, 791426 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:30,042 INFO:EPOCH 34 - PROGRESS: at 66.56% examples, 785611 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:31,058 INFO:EPOCH 34 - PROGRESS: at 78.96% examples, 710471 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:32,062 INFO:EPOCH 34 - PROGRESS: at 93.01% examples, 683286 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:32,447 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:32,456 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:32,470 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:32,471 INFO:EPOCH - 34 : training on 5514303 raw words (3735676 effective words) took 5.4s, 685705 effective words/s
# 2018-09-18 21:45:33,482 INFO:EPOCH 35 - PROGRESS: at 16.50% examples, 483572 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:34,483 INFO:EPOCH 35 - PROGRESS: at 31.08% examples, 491930 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:35,487 INFO:EPOCH 35 - PROGRESS: at 49.97% examples, 571017 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:36,502 INFO:EPOCH 35 - PROGRESS: at 64.89% examples, 573773 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:37,507 INFO:EPOCH 35 - PROGRESS: at 81.90% examples, 593760 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:38,455 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:38,470 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:38,480 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:38,481 INFO:EPOCH - 35 : training on 5514303 raw words (3736051 effective words) took 6.0s, 622558 effective words/s
# 2018-09-18 21:45:39,492 INFO:EPOCH 36 - PROGRESS: at 22.17% examples, 687322 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:40,493 INFO:EPOCH 36 - PROGRESS: at 41.04% examples, 684807 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:41,493 INFO:EPOCH 36 - PROGRESS: at 60.69% examples, 712773 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:42,494 INFO:EPOCH 36 - PROGRESS: at 78.96% examples, 715412 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:43,499 INFO:EPOCH 36 - PROGRESS: at 96.89% examples, 720648 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:43,636 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:43,652 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:43,655 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:43,656 INFO:EPOCH - 36 : training on 5514303 raw words (3736091 effective words) took 5.2s, 722639 effective words/s
# 2018-09-18 21:45:44,665 INFO:EPOCH 37 - PROGRESS: at 25.09% examples, 793774 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:45,680 INFO:EPOCH 37 - PROGRESS: at 46.95% examples, 792457 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:46,684 INFO:EPOCH 37 - PROGRESS: at 67.82% examples, 802305 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:47,689 INFO:EPOCH 37 - PROGRESS: at 88.28% examples, 805044 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:48,270 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:48,279 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:48,281 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:48,281 INFO:EPOCH - 37 : training on 5514303 raw words (3734720 effective words) took 4.6s, 808661 effective words/s
# 2018-09-18 21:45:49,293 INFO:EPOCH 38 - PROGRESS: at 25.28% examples, 796388 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:50,298 INFO:EPOCH 38 - PROGRESS: at 47.39% examples, 804122 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:51,299 INFO:EPOCH 38 - PROGRESS: at 68.31% examples, 811197 words/s, in_qsize 6, out_qsize 0
# 2018-09-18 21:45:52,303 INFO:EPOCH 38 - PROGRESS: at 88.75% examples, 811646 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:52,869 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:52,871 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:52,882 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:52,884 INFO:EPOCH - 38 : training on 5514303 raw words (3735241 effective words) took 4.6s, 812259 effective words/s
# 2018-09-18 21:45:53,892 INFO:EPOCH 39 - PROGRESS: at 25.28% examples, 799660 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:54,897 INFO:EPOCH 39 - PROGRESS: at 47.57% examples, 809595 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:55,899 INFO:EPOCH 39 - PROGRESS: at 68.31% examples, 812299 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:56,901 INFO:EPOCH 39 - PROGRESS: at 88.91% examples, 814722 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:57,453 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:45:57,457 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:45:57,468 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:45:57,469 INFO:EPOCH - 39 : training on 5514303 raw words (3736439 effective words) took 4.6s, 815850 effective words/s
# 2018-09-18 21:45:58,481 INFO:EPOCH 40 - PROGRESS: at 25.45% examples, 801662 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:45:59,485 INFO:EPOCH 40 - PROGRESS: at 47.73% examples, 810390 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:46:00,493 INFO:EPOCH 40 - PROGRESS: at 68.59% examples, 813272 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:46:01,505 INFO:EPOCH 40 - PROGRESS: at 89.33% examples, 815098 words/s, in_qsize 5, out_qsize 0
# 2018-09-18 21:46:02,034 INFO:worker thread finished; awaiting finish of 2 more threads
# 2018-09-18 21:46:02,043 INFO:worker thread finished; awaiting finish of 1 more threads
# 2018-09-18 21:46:02,046 INFO:worker thread finished; awaiting finish of 0 more threads
# 2018-09-18 21:46:02,048 INFO:EPOCH - 40 : training on 5514303 raw words (3735833 effective words) took 4.6s, 816405 effective words/s
# 2018-09-18 21:46:02,049 INFO:training on a 220572120 raw words (149440904 effective words) took 204.9s, 729257 effective words/s
# CPU times: user 8min 40s, sys: 8.68 s, total: 8min 49s
# Wall time: 4min 4s

# %%
len(model.docvecs.vectors_docs[0])

keys = list(model.docvecs.doctags.keys())
vectors = model.docvecs.vectors_docs

# %%
# %%time
#model.docvecs.vectors_docs[:10]

import numpy as np
from sklearn import cluster
from sklearn import metrics
from scipy.spatial.distance import cdist

def get_centers(model, vectors):
    number_of_clusters = len(np.unique(model.labels_))

    centers = np.zeros((number_of_clusters, DIMENSIONS))
    for i in range(0, number_of_clusters):
        cluster_points = vectors[model.labels_ == i]
        cluster_mean = np.mean(cluster_points, axis=0)
        centers[i, :] = cluster_mean

    return centers, model.labels_ 

NUM_CLUSTERS = 200

clustering = cluster.AgglomerativeClustering(affinity='euclidean', linkage='ward', 
                                             compute_full_tree=True, memory='clustercache')
clustering.set_params(n_clusters=NUM_CLUSTERS)
clustering.fit(vectors)


"""
# k means determine k
distortions = []

step = 100
K = range(2, 6000 + step, step)
for k in K:
    print(k)
    clustering.set_params(n_clusters=k)
    clustering.fit(vectors)
    distortions.append(sum(
        np.min(cdist(vectors, get_centers(clustering, vectors)[0], 'euclidean'), axis=1)) 
                       / vectors.shape[0])

    #kmeanModel = cluster.KMeans(n_clusters=k)
    #kmeanModel.fit(vectors)
    #distortions.append(sum(np.min(cdist(vectors, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / vectors.shape[0])
"""
# Out:
# CPU times: user 10.3 s, sys: 594 ms, total: 10.9 s
# Wall time: 10.9 s

# %%
##clustering.labels_

# %%
import matplotlib.pyplot as plt

def plot_elbow(K, distortions):
    # Plot the elbow
    plt.plot(K, distortions, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Distortion')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()
# Out:
# 2018-09-18 21:46:13,211 INFO:font search path ['/usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf', '/usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm', '/usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# 2018-09-18 21:46:13,570 INFO:generated new fontManager

# %%
clusters = {}
keys = list(keys)

for idx, label in enumerate(clustering.labels_):
    if not clusters.get(label):
        clusters[label] = []

    clusters[label].append(keys[idx])

print('\n--\n'.join(clusters[1]))
# Out:
# https://www.heise.de/newsticker/meldung/Missing-Link-Verschwoerungstheorien-Karl-Popper-und-die-politische-Diskussion-4117676.html?wt_mc=rss.ho.beitrag.atom
# --
# https://www.zeit.de/kultur/literatur/2018-08/vidiadhar-surajprasad-naipaul-schriftsteller-literatur-nobelpreis
# --
# https://www.zeit.de/kultur/literatur/2018-08/vidiadhar-surajprasad-naipaul-schriftsteller-literatur-nobelpreis-nachruf
# --
# https://www.zeit.de/kultur/literatur/2018-08/james-baldwin-beale-street-blues-roman
# --
# https://www.zeit.de/politik/ausland/2018-08/kofi-annan-tod-reaktionen-angela-merkel-barack-obama
# --
# https://www.zeit.de/kultur/musik/2018-08/blood-orange-negro-swan-devonte-hynes-album
# --
# https://www.zeit.de/kultur/kunst/2018-08/kunsthalle-mannheim-kunst-praesentation-rita-mcbride-jeff-wall
# --
# https://www.zeit.de/sport/2018-09/julius-thomas-nfl-doktor
# --
# https://www.zeit.de/sport/2018-09/diego-maradona-trainer-mexiko-sinaloa
# --
# http://www.spiegel.de/panorama/justiz/u-boot-mord-von-peter-madsen-rechtsmedizinerin-christian-jacobsen-ueber-die-obduktion-von-kim-wall-a-1219607.html#ref=rss
# --
# http://www.spiegel.de/wissenschaft/weltall/neil-armstrong-nachlass-wird-in-den-usa-versteigert-a-1219706.html#ref=rss
# --
# http://www.spiegel.de/einestages/turnschuh-gans-andy-capp-und-ihr-entdecker-gene-fleming-a-1216421.html#ref=rss
# --
# http://www.spiegel.de/einestages/braeune-als-schoenheitsideal-siegeszug-der-sonnenanbeter-a-1215465.html#ref=rss
# --
# http://www.spiegel.de/einestages/emmett-till-gelyncht-mit-14-jahren-us-mordfall-wird-neu-aufgerollt-a-1220008.html#ref=rss
# --
# http://www.spiegel.de/einestages/entschaedigung-fuer-sklaverei-40-morgen-land-und-ein-maulesel-a-1215241.html#ref=rss
# --
# https://www.zeit.de/2018/31/sighard-gille-kuenstler-neo-rauch-deckenfresko-leipzig
# http://www.spiegel.de/einestages/naturforscher-maxilian-zu-wied-expedition-zu-den-indianern-a-1215130.html#ref=rss
# --
# http://www.spiegel.de/einestages/mord-an-kaiserin-sisi-1898-luigi-lucheni-stach-mit-der-feile-zu-a-1226403.html#ref=rss
# --
# http://www.spiegel.de/einestages/terroranschlaege-vom-11-september-2001-zeitzeugen-berichten-a-1227562.html#ref=rss
# --
# http://www.spiegel.de/einestages/bomben-anschlag-an-der-wall-street-1920-der-vergessene-terror-a-1227531.html#ref=rss

# %%
import matplotlib

# Force matplotlib to not use any Xwindows backend.
matplotlib.use('Agg')

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA


def build_2d_vecs(vectors):
    #pca = PCA(n_components=DIMENSIONS)

    #fiftyDimVecs = pca.fit_transform(vectors)
    tsne = TSNE(n_components=2)

    two_dim_vectors = tsne.fit_transform(vectors)

    #serializable_two_dim_vectors = [vec.tolist() for vec in two_dim_vectors]

    return two_dim_vectors

print('building 2d vecs')

vecs_2d = build_2d_vecs(vectors)
# Out:
# building 2d vecs
# /var/task/env/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/local/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/var/task/env/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/var/task/env/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/local/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/usr/local/lib/python3.6/asyncio/base_events.py", line 1434, in _run_once
#     handle._run()
#   File "/usr/local/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/var/task/env/lib/python3.6/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/var/task/env/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/var/task/env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "/var/task/env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/var/task/env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/var/task/env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/var/task/env/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/var/task/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2666, in run_cell
#     self.events.trigger('post_run_cell', result)
#   File "/var/task/env/lib/python3.6/site-packages/IPython/core/events.py", line 88, in trigger
#     func(*args, **kwargs)
#   File "/var/task/env/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 164, in configure_once
#     activate_matplotlib(backend)
#   File "/var/task/env/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/var/task/env/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   """

# %%
import numpy as np
import bokeh.plotting as bp
import bokeh.models as bmo

from bokeh.plotting import save, show, reset_output
from bokeh.layouts import column

from bokeh.models import HoverTool
from bokeh.palettes import Inferno256, Viridis256, viridis
from bokeh.transform import linear_cmap

from bokeh.models import ColumnDataSource, OpenURL, TapTool
from bokeh.plotting import figure, output_file, show

bp.output_notebook()

def plot_vector(vec_2d, keys, cluster_labels, title):
    centroids = bp.ColumnDataSource({
        'c_x': [d[0] for d in vec_2d],
        'c_y': [d[1] for d in vec_2d],
        'url': [d for d in keys],
        'key': [articles_by_url[d]['text'][:50] for d in keys],
        'cluster_label': cluster_labels
    })

    plot = bp.figure(plot_width=900, plot_height=1200,
                     title=title,
                     tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave,tap",
                     x_axis_type=None, y_axis_type=None, min_border=1,
                     )

    mapper = linear_cmap(field_name='cluster_label', palette=Inferno256, low=0, high=NUM_CLUSTERS -1)

    plot.scatter(x='c_x', y='c_y',
                 color=mapper,
                 source=centroids,
                 )

    hover = plot.select(dict(type=HoverTool))
    hover.tooltips = [
        ("key", "@key"),
        ("cluster", "@cluster_label"),
    ]

    taptool = plot.select(type=TapTool)
    taptool.callback = OpenURL(url='@url')

    return plot

print('ploting...')
#reset_output()

plot = plot_vector(vecs_2d, keys, clustering.labels_, '%s articles' % len(vecs_2d))
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="af930b70-7a0d-4ece-9a40-5eb02a3d04ac">Loading BokehJS ...</span>
#     </div>
# ploting...
#   <div class="bk-root" id="d62eec0f-db49-4c90-b1ff-55c0c02bb23b"></div>
